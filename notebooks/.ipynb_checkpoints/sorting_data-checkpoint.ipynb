# %%
# Some standard import statements that are nice for Jupyter

# this is necessary for the functions.py file to be imported
import sys
sys.path.append('/ucn/orithyia_data/psi_transmission/scripts')


import os
import logging
import ipynb
import decimal
import time
import numpy as np
from scipy.optimize import curve_fit
logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# prevents the need to reload the kernel everytime functions.py file is updated
# %load_ext autoreload
# %autoreload 2

# for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.dpi'] = 200

# importing functions for analysis
from functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Sorting Data
#
# I've sorted all of the existing main detector run data into a dedicated folder, **main_detector_sorted** for analysis. Part of this involved pruning the full data set for runs that are actually worth using in analysis. This pruning was carried out by cross-referencing the information in the elog, and some plotting of the data itself.
#
# The naming convention adopted for both the .tof and .txt files is **TDDMMYY_XXXX_CONF_TYPE**, where **CONF** labels the configuration, and **TYPE** labels the run type. The options are given below.
#
# **CONF**:
#
# - NOMI - the nominal, or guide-less configuration
# - JPTI - JP Ti guide with NiP
# - JPSU - JP SUS guide with NiP
# - DISK - SS Disk
# - GD01 - UGD01 guide
# - GD03 - UGD03 guide
# - EPSU - EP SUS guide with NiP
#
# **TYPE**:
#
# - s005 - 5 second storage measurement
# - s020 - 20 second storage measurement
# - s100 - 100 second storage measurement
# - shot - direct shot measurement
#
# ## Master Run List
#
# Below is a table that lists every run of main detector data that will be used in the analysis. Runs have been omitted due to their omission from the elog, or inspection of the data and finding negligible counts.
#
# Run #'s            | Day | Storage Time (s) | NAME | Guide                             | Configuration              |
# ---                | --- |     ---          | ---  | ---                               |  ---                       |
#  22 - 24           | 8   |      20          | NOMI | None                              | TRIUMF-style Normalization |
#  25 - 31           | 8   |     100          | NOMI | None                              | TRIUMF-style Normalization |
#  32 - 35*          | 8   |       5          | NOMI | None                              | TRIUMF-style Normalization |
#       48           | 8   |  direct          | JPSU | JP SUS guide with NiP             | JP-style Test              |
#  50 - 60           | 8   |     100          | JPSU | JP SUS guide with NiP             | JP-style Test              |
#  61 - 63           | 8   |       5          | JPSU | JP SUS guide with NiP             | JP-style Test              |
#  64 - 66*          | 8   |      20          | JPSU | JP SUS guide with NiP             | JP-style Test              |
#       76           | 8   |  direct          | NOMI | None                              | TRIUMF-style Normalization |
#  77 - 79           | 8   |       5          | NOMI | None                              | TRIUMF-style Normalization |
#  80 - 82           | 8   |      20          | NOMI | None                              | TRIUMF-style Normalization |
#  83 - 88$^\dagger$ | 8   |     100          | NOMI | None                              | TRIUMF-style Normalization |
#       98           | 8   |  direct          | JPTI | JP Ti guide with NiP              | JP-style Test              |
#  99 - 105          | 8   |     100          | JPTI | JP Ti guide with NiP              | JP-style Test              |
#   1 - 90           | 9   |     100          | JPTI | JP Ti guide with NiP              | JP-style Test              |
#  99 - 101          | 9   |      20          | JPTI | JP Ti guide with NiP              | JP-style Test              |
# 102 - 110          | 9   |       5          | JPTI | JP Ti guide with NiP              | JP-style Test              |
#       120          | 9   |  direct          | NOMI | None                              | TRIUMF-style Normalization |
# 121 - 123          | 9   |       5          | NOMI | None                              | TRIUMF-style Normalization |
# 124 - 125          | 9   |      20          | NOMI | None                              | TRIUMF-style Normalization |
#       127          | 9   |      20          | NOMI | None                              | TRIUMF-style Normalization |
# 128 - 135          | 9   |     100          | NOMI | None                              | TRIUMF-style Normalization |
#       145          | 9   |  direct          | DISK | None                              | JP-style Normalization     |
# 146 - 153          | 9   |     100          | DISK | None                              | JP-style Normalization     |
# 154 - 156          | 9   |      20          | DISK | None                              | JP-style Normalization     |
# 157 - 159          | 9   |       5          | DISK | None                              | JP-style Normalization     |
#       175          | 9   |  direct          | NOMI | None                              | TRIUMF-style Normalization |
# 176 - 183          | 9   |     100          | NOMI | None                              | TRIUMF-style Normalization |
# 184 - 186          | 9   |      20          | NOMI | None                              | TRIUMF-style Normalization |
# 187 - 189          | 9   |       5          | NOMI | None                              | TRIUMF-style Normalization |
#       198          | 9   |  direct          | GD01 | UGD01, EP SUS guide               | TRIUMF-style Test          |
#       199          | 9   |     100          | GD01 | UGD01, EP SUS guide               | TRIUMF-style Test          |
#   1 - 107          | 10  |     100          | GD01 | UGD01, EP SUS guide               | TRIUMF-style Test          |
# 108 - 110          | 10  |      20          | GD01 | UGD01, EP SUS guide               | TRIUMF-style Test          |
# 111 - 113          | 10  |       5          | GD01 | UGD01, EP SUS guide               | TRIUMF-style Test          |
#       122          | 10  |  direct          | NOMI | None                              | TRIUMF-style Normalization |
# 123 - 130          | 10  |     100          | NOMI | None                              | TRIUMF-style Normalization |
# 131 - 133          | 10  |      20          | NOMI | None                              | TRIUMF-style Normalization |
# 134 - 136          | 10  |       5          | NOMI | None                              | TRIUMF-style Normalization |
#       145          | 10  |  direct          | GD03 | UGD03, EP SUS hand-polished guide | TRIUMF-style Test          |
# 146 - 155          | 10  |     100          | GD03 | UGD03, EP SUS hand-polished guide | TRIUMF-style Test          |
# 156 - 158          | 10  |      20          | GD03 | UGD03, EP SUS hand-polished guide | TRIUMF-style Test          |
# 159 - 161          | 10  |       5          | GD03 | UGD03, EP SUS hand-polished guide | TRIUMF-style Test          |
#       170          | 10  |  direct          | NOMI | None                              | TRIUMF-style Normalization |
# 172 - 179          | 10  |     100          | NOMI | None                              | TRIUMF-style Normalization |
# 180 - 182          | 10  |      20          | NOMI | None                              | TRIUMF-style Normalization |
# 183 - 185          | 10  |       5          | NOMI | None                              | TRIUMF-style Normalization |
# 193 - 194          | 10  |  direct          | EPSU | EP SUS guide with NiP             | TRIUMF-style Test          |
#       195          | 10  |     100          | EPSU | EP SUS guide with NiP             | TRIUMF-style Test          |
# 196 - 198          | 10  |       5          | EPSU | EP SUS guide with NiP             | TRIUMF-style Test          |
# 199 - 201          | 10  |      20          | EPSU | EP SUS guide with NiP             | TRIUMF-style Test          |
# 202 - 241          | 10  |     100          | EPSU | EP SUS guide with NiP             | TRIUMF-style Test          |
#       249          | 10  |  direct          | NOMI | None                              | TRIUMF-style Normalization |
# 250 - 252          | 10  |       5          | NOMI | None                              | TRIUMF-style Normalization |
# 253 - 255          | 10  |      20          | NOMI | None                              | TRIUMF-style Normalization |
# 256 - 265          | 10  |     100          | NOMI | None                              | TRIUMF-style Normalization |
#
# \* elog: *configuration change, background included* - cut required.<br/>
# $^\dagger$ elog: *to be checked in the data (remove noise at the end)* - cut required<br/>

# %% [markdown]
# ## Cuts to Dec. 8th runs: 35, 66, and 88
#
# As noted in the table above, and in the elog, there are a couple of runs that require cuts of the spectrum.

# %%
fig, ax1 = plt.subplots()
fig, ax2 = plt.subplots()
fig, ax3 = plt.subplots()

data = np.loadtxt("../data_ucn/main_detector/8/T081217_0035.tof", usecols = (0,1));
ax1.plot(data[:,0] * 0.1, data[:,1]);
ax1.set_ylabel('UCN counts');
ax1.set_xlabel('Time [s]');
ax1.set_title('Run 35, Dec. 8, 5s storage');

data = np.loadtxt("../data_ucn/main_detector/8/T081217_0066.tof", usecols = (0,1));
ax2.plot(data[:,0] * 0.1, data[:,1]);
ax2.set_ylabel('UCN counts');
ax2.set_xlabel('Time [s]');
ax2.set_title('Run 66, Dec. 8, 20s storage');

data = np.loadtxt("../data_ucn/main_detector/8/T081217_0088.tof", usecols = (0,1));
ax3.plot(data[:,0] * 0.1, data[:,1]);
ax3.set_ylabel('UCN counts');
ax3.set_xlabel('Time [s]');
ax3.set_title('Run 88, Dec. 8, 100s storage');

# %% [markdown]
# In all three of these runs there is a blip of counts that follows the main peak. These abberations are due to unexpected noise, or configuration issues. Appropriate cuts in time to these specific runs are applied when data is loaded via the functions:
#
# ```python
# load_data()
# load_all_data()
# ```
